# %%
# %matplotlib inline

# %%
from quantaccel.tmat_simulation import RunResult
import pickle
import os
import re

# %%
results = list()
walkydir = '../muller2/'
#walkydir = '../tmat/'
for dirpath, dirnames, filenames in os.walk(walkydir):
    for fn in filenames:
        if re.match("tmatfromass-round.kl.pickl", fn):
            with open(os.path.join(dirpath, fn)) as f:
                results.append(pickle.load(f))

# %%
for r in results: print r.params
print "Number of them: ", len(results)
# Out:
# {'ll': '100'}
# {'ll': '5'}
# {'ll': '500'}
# {'ll': '1000'}
# {'ll': '20'}
# {'ll': '1'}
# {'lpt': '100k'}
# {'lpt': '500'}
# {'lpt': '2k'}
# {'lpt': '50k'}
# {'lpt': '10k'}
# Number of them:  11

# %%
from operator import itemgetter
for r in results:
    r.errors = np.abs(r.errors)
    r.errors = np.sort(r.errors, axis=1)

# %%
for r in results[:]:
    pp.plot(r.errors[0], r.errors[1], '-', label=str(r.params))
    pp.title(str(r.params))
    pp.show()
