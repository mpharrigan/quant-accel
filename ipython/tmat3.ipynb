# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
cd ~/projects/quant-accel/
# Out:
# /home/harrigan/projects/quant-accel

# %%
from __future__ import division
from matplotlib import pyplot as plt
from quantaccel import speedcalc as sc
from maccelerator import datavis as dv
from quantaccel.tmat_simulation import RunResult
import pickle
import os
import re
# Out:
# /usr/lib/pymodules/python2.7/matplotlib/__init__.py:1035: UserWarning:  This call to matplotlib.use() has no effect
# because the the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
tmat = sc.TmatResults()
tmat.load('/home/harrigan/biox/projects/quant-accel/tmat-2-newsamp/', 'k')
# Out:
# INFO:root:Loaded 868 points

# %% [markdown]
# # Convergence over time
# ## Population
# Note that there are some differences in this code for tmat vs. muller: spt -> n_spt, etc

# %%
dv.convergence_plots(tmat, 7)

# %%
tmat.speed_pop(tvd_cutoff=0.4)

# %%
rounds_vs_spt = tmat.plot_vs('pop', 'rounds', xaxis='n_spt', label='n_tpr')

# %% [markdown]
# # Histograms

# %%
dv.histograms(rounds_vs_spt, whole_range=True, log_plot=True)
# Out:
# WARNING:root:8.000000 is too skinny. Using counts

# %% [markdown]
# ## Number of rounds goes down

# %%
dv.plot_avgs(rounds_vs_spt)

# %%
dv.speed_figs(rounds_vs_spt, naw)

# %% [markdown]
# # Fitting

# %% [markdown]
# # Non-adaptive

# %%
tmat.speed_pop(tvd_cutoff=0.4, name='non')
time_vs_spt_na = tmat.plot_vs('non', 'time', xaxis='n_spt', label='n_tpr')
time_vs_tpr_na = tmat.plot_vs('non', 'time', xaxis='n_tpr', label='adaptive')

# %%
dv.histograms(time_vs_tpr_na, whole_range=True, log=True, shoop=True)

# %%
naw = dv.na_plot(time_vs_tpr_na)
