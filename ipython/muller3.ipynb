# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
cd ~/projects/quant-accel/
# Out:
# /home/harrigan/projects/quant-accel

# %%
from __future__ import division
from matplotlib import pyplot as plt
from quantaccel import speedcalc as sc
import pickle
import os
import re
# Out:
# /usr/lib/pymodules/python2.7/matplotlib/__init__.py:1035: UserWarning:  This call to matplotlib.use() has no effect
# because the the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
# Load results
muller = sc.MullerResults()
muller.load_from_biox('projection-pop')
# Out:
# INFO:root:Loaded 1289 points

# %%
# Calculate speeds
muller.speed_pop(tvd_cutoff=0.6)

# %%
muller.subdivide = muller.load('/home/harrigan/biox/projects/quant-accel/muller4/projection-pop-subfilelist.dat',
                                '/home/harrigan/biox/projects/quant-accel/muller4/')

# %%
muller.speed_subdivide_pop(tvd_cutoff=0.6)
# Out:
# WARNING:root:Couldn't find subdivide (0): {'lt': 20, 'runcopy': 22, 'spt': 40416, 'tpr': 10}
# WARNING:root:Couldn't find subdivide (0): {'lt': 20, 'runcopy': 22, 'spt': 5052, 'tpr': 10}
# WARNING:root:Couldn't find subdivide (0): {'lt': 20, 'runcopy': 22, 'spt': 1280, 'tpr': 500}
# WARNING:root:Couldn't find subdivide (0): {'lt': 20, 'runcopy': 22, 'spt': 20208, 'tpr': 10}
# WARNING:root:Couldn't find subdivide (0): {'lt': 20, 'runcopy': 22, 'spt': 40416, 'tpr': 1}
# WARNING:root:Couldn't find subdivide (0): {'lt': 20, 'runcopy': 22, 'spt': 2560, 'tpr': 100}
# WARNING:root:Couldn't find subdivide (0): {'lt': 20, 'runcopy': 25, 'spt': 40416, 'tpr': 10}
# WARNING:root:Couldn't find subdivide (0): {'lt': 20, 'runcopy': 25, 'spt': 5052, 'tpr': 10}
# WARNING:root:Couldn't find subdivide (0): {'lt': 20, 'runcopy': 25, 'spt': 20208, 'tpr': 10}
# WARNING:root:Couldn't find subdivide (0): {'lt': 20, 'runcopy': 25, 'spt': 2560, 'tpr': 100}
# WARNING:root:Couldn't find subdivide (0): {'lt': 20, 'runcopy': 27, 'spt': 2560, 'tpr': 1}
# WARNING:root:Couldn't find subdivide (0): {'lt': 20, 'runcopy': 27, 'spt': 40416, 'tpr': 10}
# WARNING:root:Couldn't find subdivide (0): {'lt': 20, 'runcopy': 27, 'spt': 2560, 'tpr': 100}
# WARNING:root:Couldn't find subdivide (0): {'lt': 20, 'runcopy': 24, 'spt': 2560, 'tpr': 10}
# WARNING:root:Couldn't find subdivide (0): {'lt': 20, 'runcopy': 24, 'spt': 40416, 'tpr': 10}
# WARNING:root:Couldn't find subdivide (0): {'lt': 20, 'runcopy': 24, 'spt': 20208, 'tpr': 10}
# WARNING:root:Couldn't find subdivide (0): {'lt': 20, 'runcopy': 24, 'spt': 40416, 'tpr': 1}
# WARNING:root:Couldn't find subdivide (0): {'lt': 20, 'runcopy': 24, 'spt': 10104, 'tpr': 10}
# WARNING:root:Couldn't find subdivide (0): {'lt': 20, 'runcopy': 24, 'spt': 2560, 'tpr': 100}
# WARNING:root:Couldn't find subdivide (0): {'lt': 20, 'runcopy': 23, 'spt': 10104, 'tpr': 1}
# WARNING:root:Couldn't find subdivide (0): {'lt': 20, 'runcopy': 23, 'spt': 40416, 'tpr': 10}
# WARNING:root:Couldn't find subdivide (0): {'lt': 20, 'runcopy': 23, 'spt': 10104, 'tpr': 10}
# WARNING:root:Couldn't find subdivide (0): {'lt': 20, 'runcopy': 23, 'spt': 2560, 'tpr': 100}
# WARNING:root:Couldn't find subdivide (0): {'lt': 20, 'runcopy': 29, 'spt': 10104, 'tpr': 1}
# WARNING:root:Couldn't find subdivide (0): {'lt': 20, 'runcopy': 29, 'spt': 40416, 'tpr': 10}
# WARNING:root:Couldn't find subdivide (0): {'lt': 20, 'runcopy': 29, 'spt': 20208, 'tpr': 1}
# WARNING:root:Couldn't find subdivide (0): {'lt': 20, 'runcopy': 29, 'spt': 5052, 'tpr': 1}
# WARNING:root:Couldn't find subdivide (0): {'lt': 20, 'runcopy': 29, 'spt': 10104, 'tpr': 10}
# WARNING:root:Couldn't find subdivide (0): {'lt': 20, 'runcopy': 29, 'spt': 2560, 'tpr': 100}
# WARNING:root:Couldn't find subdivide (0): {'lt': 20, 'runcopy': 28, 'spt': 2560, 'tpr': 1}
# WARNING:root:Couldn't find subdivide (0): {'lt': 20, 'runcopy': 28, 'spt': 40416, 'tpr': 10}
# WARNING:root:Couldn't find subdivide (0): {'lt': 20, 'runcopy': 28, 'spt': 5052, 'tpr': 10}
# WARNING:root:Couldn't find subdivide (0): {'lt': 20, 'runcopy': 28, 'spt': 5052, 'tpr': 1}
# WARNING:root:Couldn't find subdivide (0): {'lt': 20, 'runcopy': 28, 'spt': 20208, 'tpr': 10}
# WARNING:root:Couldn't find subdivide (0): {'lt': 20, 'runcopy': 28, 'spt': 40416, 'tpr': 1}
# WARNING:root:Couldn't find subdivide (0): {'lt': 20, 'runcopy': 28, 'spt': 2560, 'tpr': 100}
# WARNING:root:Couldn't find subdivide (0): {'lt': 20, 'runcopy': 21, 'spt': 40416, 'tpr': 10}
# WARNING:root:Couldn't find subdivide (0): {'lt': 20, 'runcopy': 21, 'spt': 640, 'tpr': 500}
# WARNING:root:Couldn't find subdivide (0): {'lt': 20, 'runcopy': 21, 'spt': 20208, 'tpr': 10}
# WARNING:root:Couldn't find subdivide (0): {'lt': 20, 'runcopy': 21, 'spt': 40416, 'tpr': 1}
# WARNING:root:Couldn't find subdivide (0): {'lt': 20, 'runcopy': 21, 'spt': 10104, 'tpr': 10}
# WARNING:root:Couldn't find subdivide (0): {'lt': 20, 'runcopy': 21, 'spt': 2560, 'tpr': 100}
# WARNING:root:Couldn't find subdivide (0): {'lt': 20, 'runcopy': 26, 'spt': 40416, 'tpr': 10}
# WARNING:root:Couldn't find subdivide (0): {'lt': 20, 'runcopy': 26, 'spt': 10104, 'tpr': 10}
# WARNING:root:Couldn't find subdivide (0): {'lt': 20, 'runcopy': 26, 'spt': 2560, 'tpr': 100}
# WARNING:root:Couldn't find subdivide (0): {'lt': 20, 'runcopy': 20, 'spt': 40416, 'tpr': 10}
# WARNING:root:Couldn't find subdivide (0): {'lt': 20, 'runcopy': 20, 'spt': 1280, 'tpr': 500}
# WARNING:root:Couldn't find subdivide (0): {'lt': 20, 'runcopy': 20, 'spt': 20208, 'tpr': 10}
# WARNING:root:Couldn't find subdivide (0): {'lt': 20, 'runcopy': 20, 'spt': 40416, 'tpr': 1}
# WARNING:root:Couldn't find subdivide (0): {'lt': 20, 'runcopy': 20, 'spt': 10104, 'tpr': 10}
# WARNING:root:Couldn't find subdivide (0): {'lt': 20, 'runcopy': 20, 'spt': 2560, 'tpr': 100}

# %% [markdown]
# #Convergence over time
# ## Population
# We visualize convergence (as defined by equilibrium population total variational distance (TVD)) over time. Each colored line is a a certain degree of parallelization (tpr) and each plot is at a certain round length (spt)

# %%
uniques = muller.get_unique('pop', ('lt', 'spt'))
uniques = [(ss, ax) for ax, (sv, ss) in enumerate(uniques)]
uniqued = dict(uniques)
fig, axes = plt.subplots(3, 3, figsize=(16,12))
for r in muller.get_runcopy(7, 'pop'):
    paramtuple = (r.params['lt'], r.params['spt'])
    figname = "lt-%s_spt-%s" % paramtuple
    ax = axes[np.unravel_index(uniqued[figname], axes.shape)]
    ax.plot(r.errors[:,0], r.errors[:,1], '.-', label=r.params['tpr'])
    ax.set_title("LT %s, SPT %s" % paramtuple)
    ax.set_xlabel('walltime'); ax.set_ylabel('eq pop TVD')
    ax.axhline(0.6, c='r')
    ax.set_xscale('log')

# %% [markdown]
# ## Number of rounds vs. steps per traj

# %%
rounds_vs_spt = muller.plot_vs('pop', 'rounds', xaxis='spt', label='tpr')

# %% [markdown]
# ## Histograms
# We show that the number of rounds is non-skew distributed on a log scale

# %%
fig, axes = plt.subplots(8, 5, figsize=(16, 4*8))
for i, (k, v) in enumerate(rounds_vs_spt.items()):
    for j, (hist, bin_centers, xval) in enumerate(sc.histogram(v, n_bins=10, whole_range=False, log=False)):
        ax = axes[j, i]
        ax.plot(bin_centers, hist, 'o-')
        ax.set_xlabel('# of rounds');
        ax.set_title("tpr: %s spt: %s" % (k, xval))

# %%
fig, axes = plt.subplots(8, 5, figsize=(16, 4*8))
for i, (k, v) in enumerate(rounds_vs_spt.items()):
    for j, (hist, bin_centers, xval) in enumerate(sc.histogram(v, n_bins=10, whole_range=False, log=True)):
        ax = axes[j, i]
        ax.plot(bin_centers, hist, 'o-')
        ax.set_xlabel('log(# of rounds)');
        ax.set_title("tpr: %s spt: %s" % (k, xval))

# %%
for k, v in rounds_vs_spt.items():
    w = sc.avg_and_errorbar(v)
    pp.errorbar(w[:,0], w[:,1], yerr=None, fmt='o-', label=k)
    
    # indent or dedent the following
pp.axhline(1, c='grey')
pp.xscale('log'); pp.yscale('log')
pp.xlabel('Steps per traj'); pp.ylabel('Rounds')
pp.legend(loc='lower right', bbox_to_anchor=((1.5,0.0)))
pp.show()

# %% [markdown]
# ### Fit things

# %%
for r in muller._get_by_name('pop'):
    if r.popind > 10 and r.params['tpr'] >= 100 and r.params['spt'] > 500:
        print r.popind, r.params
# Out:
# 20 {'lt': 20, 'runcopy': 8, 'spt': 1280, 'tpr': 1000}
# 16 {'lt': 20, 'runcopy': 8, 'spt': 2560, 'tpr': 500}
# 49 {'lt': 20, 'runcopy': 8, 'spt': 640, 'tpr': 1000}
# 12 {'lt': 20, 'runcopy': 8, 'spt': 2560, 'tpr': 1000}
# 34 {'lt': 20, 'runcopy': 8, 'spt': 1280, 'tpr': 500}
# 25 {'lt': 20, 'runcopy': 14, 'spt': 2560, 'tpr': 100}
# 28 {'lt': 20, 'runcopy': 14, 'spt': 1280, 'tpr': 1000}
# 15 {'lt': 20, 'runcopy': 14, 'spt': 2560, 'tpr': 500}
# 30 {'lt': 20, 'runcopy': 14, 'spt': 1280, 'tpr': 500}
# 28 {'lt': 20, 'runcopy': 17, 'spt': 2560, 'tpr': 100}
# 24 {'lt': 20, 'runcopy': 17, 'spt': 1280, 'tpr': 1000}
# 14 {'lt': 20, 'runcopy': 17, 'spt': 2560, 'tpr': 500}
# 13 {'lt': 20, 'runcopy': 17, 'spt': 2560, 'tpr': 1000}
# 27 {'lt': 20, 'runcopy': 17, 'spt': 1280, 'tpr': 500}
# 33 {'lt': 20, 'runcopy': 6, 'spt': 1280, 'tpr': 1000}
# 38 {'lt': 20, 'runcopy': 6, 'spt': 1280, 'tpr': 100}
# 14 {'lt': 20, 'runcopy': 6, 'spt': 2560, 'tpr': 500}
# 11 {'lt': 20, 'runcopy': 6, 'spt': 2560, 'tpr': 1000}
# 45 {'lt': 20, 'runcopy': 6, 'spt': 1280, 'tpr': 500}
# 22 {'lt': 20, 'runcopy': 19, 'spt': 2560, 'tpr': 100}
# 20 {'lt': 20, 'runcopy': 19, 'spt': 1280, 'tpr': 1000}
# 49 {'lt': 20, 'runcopy': 19, 'spt': 1280, 'tpr': 100}
# 32 {'lt': 20, 'runcopy': 19, 'spt': 2560, 'tpr': 500}
# 40 {'lt': 20, 'runcopy': 13, 'spt': 2560, 'tpr': 100}
# 23 {'lt': 20, 'runcopy': 13, 'spt': 1280, 'tpr': 1000}
# 19 {'lt': 20, 'runcopy': 13, 'spt': 2560, 'tpr': 500}
# 46 {'lt': 20, 'runcopy': 13, 'spt': 640, 'tpr': 1000}
# 12 {'lt': 20, 'runcopy': 13, 'spt': 2560, 'tpr': 1000}
# 31 {'lt': 20, 'runcopy': 7, 'spt': 2560, 'tpr': 100}
# 28 {'lt': 20, 'runcopy': 7, 'spt': 1280, 'tpr': 1000}
# 17 {'lt': 20, 'runcopy': 7, 'spt': 2560, 'tpr': 500}
# 37 {'lt': 20, 'runcopy': 7, 'spt': 1280, 'tpr': 500}
# 23 {'lt': 20, 'runcopy': 9, 'spt': 2560, 'tpr': 100}
# 22 {'lt': 20, 'runcopy': 9, 'spt': 1280, 'tpr': 1000}
# 13 {'lt': 20, 'runcopy': 9, 'spt': 2560, 'tpr': 500}
# 14 {'lt': 20, 'runcopy': 9, 'spt': 2560, 'tpr': 1000}
# 25 {'lt': 20, 'runcopy': 9, 'spt': 1280, 'tpr': 500}
# 29 {'lt': 20, 'runcopy': 3, 'spt': 2560, 'tpr': 100}
# 31 {'lt': 20, 'runcopy': 3, 'spt': 1280, 'tpr': 1000}
# 21 {'lt': 20, 'runcopy': 3, 'spt': 2560, 'tpr': 500}
# 38 {'lt': 20, 'runcopy': 3, 'spt': 640, 'tpr': 1000}
# 12 {'lt': 20, 'runcopy': 3, 'spt': 2560, 'tpr': 1000}
# 35 {'lt': 20, 'runcopy': 5, 'spt': 2560, 'tpr': 100}
# 34 {'lt': 20, 'runcopy': 5, 'spt': 1280, 'tpr': 1000}
# 22 {'lt': 20, 'runcopy': 5, 'spt': 2560, 'tpr': 500}
# 11 {'lt': 20, 'runcopy': 5, 'spt': 2560, 'tpr': 1000}
# 26 {'lt': 20, 'runcopy': 5, 'spt': 1280, 'tpr': 500}
# 24 {'lt': 20, 'runcopy': 15, 'spt': 1280, 'tpr': 1000}
# 11 {'lt': 20, 'runcopy': 15, 'spt': 2560, 'tpr': 500}
# 28 {'lt': 20, 'runcopy': 15, 'spt': 1280, 'tpr': 500}
# 34 {'lt': 20, 'runcopy': 10, 'spt': 2560, 'tpr': 100}
# 30 {'lt': 20, 'runcopy': 10, 'spt': 1280, 'tpr': 1000}
# 18 {'lt': 20, 'runcopy': 10, 'spt': 2560, 'tpr': 500}
# 42 {'lt': 20, 'runcopy': 10, 'spt': 640, 'tpr': 1000}
# 16 {'lt': 20, 'runcopy': 10, 'spt': 2560, 'tpr': 1000}
# 29 {'lt': 20, 'runcopy': 10, 'spt': 1280, 'tpr': 500}
# 37 {'lt': 20, 'runcopy': 16, 'spt': 2560, 'tpr': 100}
# 28 {'lt': 20, 'runcopy': 16, 'spt': 1280, 'tpr': 1000}
# 13 {'lt': 20, 'runcopy': 16, 'spt': 2560, 'tpr': 500}
# 38 {'lt': 20, 'runcopy': 16, 'spt': 640, 'tpr': 1000}
# 31 {'lt': 20, 'runcopy': 16, 'spt': 1280, 'tpr': 500}
# 32 {'lt': 20, 'runcopy': 4, 'spt': 2560, 'tpr': 100}
# 23 {'lt': 20, 'runcopy': 4, 'spt': 1280, 'tpr': 1000}
# 43 {'lt': 20, 'runcopy': 4, 'spt': 1280, 'tpr': 100}
# 15 {'lt': 20, 'runcopy': 4, 'spt': 2560, 'tpr': 500}
# 26 {'lt': 20, 'runcopy': 4, 'spt': 1280, 'tpr': 500}
# 27 {'lt': 20, 'runcopy': 12, 'spt': 2560, 'tpr': 100}
# 24 {'lt': 20, 'runcopy': 12, 'spt': 1280, 'tpr': 1000}
# 14 {'lt': 20, 'runcopy': 12, 'spt': 2560, 'tpr': 500}
# 34 {'lt': 20, 'runcopy': 12, 'spt': 1280, 'tpr': 500}
# 41 {'lt': 20, 'runcopy': 11, 'spt': 2560, 'tpr': 100}
# 24 {'lt': 20, 'runcopy': 11, 'spt': 1280, 'tpr': 1000}
# 26 {'lt': 20, 'runcopy': 11, 'spt': 2560, 'tpr': 500}
# 13 {'lt': 20, 'runcopy': 11, 'spt': 2560, 'tpr': 1000}
# 40 {'lt': 20, 'runcopy': 11, 'spt': 1280, 'tpr': 500}
# 22 {'lt': 20, 'runcopy': 18, 'spt': 2560, 'tpr': 100}
# 24 {'lt': 20, 'runcopy': 18, 'spt': 1280, 'tpr': 1000}
# 12 {'lt': 20, 'runcopy': 18, 'spt': 2560, 'tpr': 500}
# 16 {'lt': 20, 'runcopy': 18, 'spt': 2560, 'tpr': 1000}
# 33 {'lt': 20, 'runcopy': 18, 'spt': 1280, 'tpr': 500}
# 22 {'lt': 20, 'runcopy': 18, 'spt': 2560, 'tpr': 100}

# %%
rounds_vs_spt = muller.plot_vs('pop', 'rounds', xaxis='spt', label='tpr')
# One traj normalization
one_traj_fit = sc.FitResult(1, rounds_vs_spt[1])
one_traj_fit.fit_vs_spt(1.0)
rounds_vs_spt.otf = one_traj_fit
sfig, sax = pp.subplots()
tfig, tax = pp.subplots()
for fit in rounds_vs_spt.enum_fit():
    cfig, (ax1, ax2) = pp.subplots(1,2, figsize=(16,5))
    
    # Scatter points
    ax1.scatter(fit.x, fit.y)
    
    # Plot fit
    ax1.plot(fit.fitx, fit.fity, 'b-')    
    
    # Plot non-adaptive
    ax1.plot(fit.fitx, fit.na_scale, 'r-', label='Non-adaptive')
    
    # Plot Rounds = 1
    ax1.axhline(1.0, c='grey')
    
    # Plot speed on right and on top fig
    ax2.plot(fit.fitx, fit.fit_time, '-')
    ax2.scatter(fit.x, fit.dat_time)
    
    sax.plot(fit.fitx, fit.speedup, '-', label=fit.key)
    tax.plot(fit.fitx, fit.speed, '-', label=fit.key)
    
    # Format
    ax1.set_xscale('log'); ax1.set_yscale('log')
    ax1.set_xlabel('Steps per traj'); ax1.set_ylabel('Rounds')
    ax1.set_title('Tpr %s' % fit.key)
    
    ax2.set_xlabel('spt'); ax2.set_ylabel('time')
    ax2.set_xscale('log'); #ax2.set_yscale('log')

sax.set_xlabel('spt'); sax.set_ylabel('speedup')
sax.set_xscale('log'); sax.set_yscale('log')
sax.legend(loc='lower right', bbox_to_anchor=((1.5,0.0)))

tax.set_xlabel('spt'); tax.set_ylabel('speedup to tpr=1')
tax.set_xscale('log'); tax.set_yscale('log')
tax.legend(loc='lower right', bbox_to_anchor=((1.5,0.0)))
# Out:
# INFO:root:41490.7094678
# INFO:root:41490.7094678
# INFO:root:13013.6958932
# INFO:root:11537.4309542
# INFO:root:161208.508394
# INFO:root:522166.054875

# %% [markdown]
# ## Number of rounds vs. Trajectories per round

# %%
rounds_vs_tpr = muller.plot_vs('pop', 'rounds', xaxis='tpr', label='spt')

# %%
for k, v in rounds_vs_tpr.items():
    w = sc.avg_and_errorbar(v)
    pp.errorbar(w[:,0], w[:,1], yerr=None, fmt='o-', label=k)
    
    # indent or dedent the following
pp.xscale('log'); pp.yscale('log')
pp.xlabel('Trajs per round'); pp.ylabel('Rounds')
pp.legend(loc='lower right', bbox_to_anchor=((1.5,0.0)))
pp.show()

# %%
rounds_vs_tpr = muller.plot_vs('pop', 'rounds', xaxis='tpr', label='spt')
# One traj normalization
one_traj_fit = sc.FitResult(1, rounds_vs_spt[1])
one_traj_fit.fit_vs_spt(1.0)
rounds_vs_tpr.otf = one_traj_fit
sfig, sax = pp.subplots()
tfig, tax = pp.subplots()
for fit in rounds_vs_tpr.enum_fit():
    cfig, (ax1, ax2) = pp.subplots(1,2, figsize=(16,5))
    
    # Scatter points
    ax1.scatter(fit.x, fit.y)
    
    # Plot fit
    ax1.plot(fit.fitx, fit.fity, 'b-')    
    
    
    # Plot speed on right and on top fig
    ax2.plot(fit.fitx, fit.fit_time, '-')
    ax2.scatter(fit.x, fit.dat_time)
    
    sax.plot(fit.fitx, fit.speedup, '-', label=fit.key)
    tax.plot(fit.fitx, fit.speed, '-', label=fit.key)
    
    # Format
    ax1.set_xscale('log'); ax1.set_yscale('log')
    ax1.set_xlabel('Traj per round'); ax1.set_ylabel('Rounds')
    ax1.set_title('spt %s' % fit.key)
    
    ax2.set_xlabel('tpr'); ax2.set_ylabel('time')
    ax2.set_xscale('log'); #ax2.set_yscale('log')

sax.set_xlabel('tpr'); sax.set_ylabel('speedup')
sax.set_xscale('log'); #sax.set_yscale('log')
sax.legend(loc='lower right', bbox_to_anchor=((1.5,0.0)))

tax.set_xlabel('tpr'); tax.set_ylabel('speedup to tpr=1')
tax.set_xscale('log'); tax.set_yscale('log')
tax.legend(loc='lower right', bbox_to_anchor=((1.5,0.0)))

# %%
import itertools

# %%
spts = [21, 40, 80, 160, 320, 640, 1280, 2560]
tprs = [1, 10, 100, 500, 1000]
lagtimes = [20]

# %%
ll = list(itertools.product(spts, tprs, lagtimes))
print ll
# Out:
# [(21, 1, 20), (21, 10, 20), (21, 100, 20), (21, 500, 20), (21, 1000, 20), (40, 1, 20), (40, 10, 20), (40, 100, 20), (40, 500, 20), (40, 1000, 20), (80, 1, 20), (80, 10, 20), (80, 100, 20), (80, 500, 20), (80, 1000, 20), (160, 1, 20), (160, 10, 20), (160, 100, 20), (160, 500, 20), (160, 1000, 20), (320, 1, 20), (320, 10, 20), (320, 100, 20), (320, 500, 20), (320, 1000, 20), (640, 1, 20), (640, 10, 20), (640, 100, 20), (640, 500, 20), (640, 1000, 20), (1280, 1, 20), (1280, 10, 20), (1280, 100, 20), (1280, 500, 20), (1280, 1000, 20), (2560, 1, 20), (2560, 10, 20), (2560, 100, 20), (2560, 500, 20), (2560, 1000, 20)]

# %%
print 2526*2
print 2526*2*2
print 2526*2*2*2
print 2526*2*2*2*2
# Out:
# 5052
# 10104
# 20208
# 40416
